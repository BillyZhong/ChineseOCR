# %%
import webbrowser
import urllib

from pynput import keyboard
from pynput.mouse import Controller
import pyautogui

import numpy as np
import cv2
from PIL import Image

import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
im = cv2.imread('b.png',0)
plt.imshow(im, cmap="gray")

# %%
t, im_thresh = cv2.threshold(im,200,255,cv2.THRESH_BINARY)
plt.imshow(im_thresh)
